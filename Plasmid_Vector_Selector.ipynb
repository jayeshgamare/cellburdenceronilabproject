# %%
## read the excel file called WPL_Run-1_Data_Analysis.xlsx

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# read the excel file
df = pd.read_excel('WPL_Run-1_Data_Analysis .xlsx', sheet_name='Analysis') # Insert name of the excel file and sheet you are reading the nanopore sequencing data

# print the first 5 rows of the data frame
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1    Unnamed: 2   Unnamed: 3 Number of aligned reads  \
# 0         NaN        NaN  Plasmid Size  Insert Size            Before Assay
# 1         NaN   MTK1_008          2448          786                      75
# 2         NaN   MTK1_009          2448          786                      54
# 3         NaN   MTK1_010          2448          786                      51
# 4         NaN   MTK1_011          2448          786                     197
#
#     Unnamed: 5 Percentage of part from total successful alignments Unnamed: 7  \
# 0  After Assay                                             Before       After
# 1          179                                            0.20676    0.515286
# 2          156                                           0.148867    0.449076
# 3           17                                           0.140597    0.048938
# 4           95                                           0.543089    0.273476
#
# ...

# %% [markdown]
# # New section

# %%
# seperate the data into two groups one for which Percentage difference is positive and other for which it is negative, preserve the index

# df_pos = df[df['Percentage difference '] > 0]
# df_neg = df[df['Percentage difference '] < 0]

# %%
# plot the histogram for the positive percentage difference

plt.hist(df['Percentage difference '], bins=10, color='green')
# Out:
# (array([  1.,   1.,   2.,   9., 191.,   2.,   0.,   1.,   0.,   1.]),
#  array([-5.54824181, -4.33591503, -3.12358825, -1.91126147, -0.69893469,
#          0.51339209,  1.72571887,  2.93804565,  4.15037243,  5.36269922,
#          6.575026  ]),
#  <BarContainer object of 10 artists>)

# %%
# find the mean and filter the data greater than mean

alpha = 2

mean = df['Percentage difference '].abs().mean()
df_mean = df[df['Percentage difference '].abs() > alpha*pos_mean]

# %%
df_pos_mean
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Number of aligned reads  \
# 5           NaN    MTK1_012       2448        786                     620
# 29          NaN    MTK2_004       2194        532                     319
# 31          NaN    MTK2_006       2096        434                      29
# 45          NaN    MTK2_023       2277        615                      48
# 48          NaN    MTK2_026       2176        514                     178
# 58          NaN    MTK3_016       2928       1266                     718
# 60          NaN    MTK3_018       3537       1875                     981
# 61          NaN    MTK3_019       3258       1596                     836
# 64          NaN    MTK3_027       3924       2262                    3298
# 65          NaN    MTK3_029       3360       1698                     466
# 66          NaN    MTK3_030       3912       2250                     621
# 69          NaN    MTK3_033       4293       2631                    1077
# ...

# %%
# find the mean and filter the data greater than mean

# alpha = 2

# neg_mean = df['Percentage difference '].mean()
# df_neg_mean = df[df['Percentage difference '] < alpha*neg_mean]

# %%
df_neg_mean
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Number of aligned reads  \
# 3           NaN    MTK1_010       2448        786                      51
# 4           NaN    MTK1_011       2448        786                     197
# 5           NaN    MTK1_012       2448        786                     620
# 6           NaN    MTK1_013       2448        786                     624
# 8           NaN    MTK1_015       2482        820                     117
# ..          ...         ...        ...        ...                     ...
# 199         NaN  MTK234_038       2094        432                      22
# 200         NaN  MTK234_050       3087       1425                     269
# 202         NaN  MTK234_055       3075       1413                     493
# 203         NaN  MTK234_056       3034       1372                     201
# 207         NaN      pTC_13       1895        233                     575
#
#     Unnamed: 5 Percentage of part from total successful alignments Unnamed: 7  \
# ...

# %%
df_pos = df_mean[df_mean['Percentage difference '] > 0]
df_neg = df_mean[df_mean['Percentage difference '] < 0]

# %%
df_pos
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Number of aligned reads  \
# 29         NaN   MTK2_004       2194        532                     319
# 31         NaN   MTK2_006       2096        434                      29
# 45         NaN   MTK2_023       2277        615                      48
# 48         NaN   MTK2_026       2176        514                     178
#
#    Unnamed: 5 Percentage of part from total successful alignments Unnamed: 7  \
# 29       1484                                           0.879418    4.271979
# 31        525                                           0.079947    1.511313
# 45       2330                                           0.132326    6.707352
# 48        549                                            0.49071    1.580402
#
#     Percentage difference   Unnamed: 9  ...  Unnamed: 24  Unnamed: 25  \
# 29                3.392561         NaN  ...          NaN          NaN
# 31                1.431366         NaN  ...          NaN          NaN
# ...

# %%
df_neg
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Number of aligned reads  \
# 5           NaN    MTK1_012       2448        786                     620
# 58          NaN    MTK3_016       2928       1266                     718
# 60          NaN    MTK3_018       3537       1875                     981
# 61          NaN    MTK3_019       3258       1596                     836
# 64          NaN    MTK3_027       3924       2262                    3298
# 65          NaN    MTK3_029       3360       1698                     466
# 66          NaN    MTK3_030       3912       2250                     621
# 69          NaN    MTK3_033       4293       2631                    1077
# 70          NaN    MTK3_034       3807       2145                    1545
# 71          NaN    MTK3_035       4311       2649                    1383
# 160         NaN    MTK6_014       4010       2348                    1280
# 202         NaN  MTK234_055       3075       1413                     493
#
# ...
